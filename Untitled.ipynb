# %% [markdown]
# Pythone script to call the API and print the data in json format

# %%
pip install requests

# %% [markdown]
# #This lines of code will connect  Alpha Vantage to pull the data from list of top 10 companies and Historical dump of data in CSV format.

# %%
import requests
import pandas as pd

# Define your API base URL and API key
base_url = "https://www.alphavantage.co/query"
api_key = "your_api_key_here"  # Replace with your actual API key

# List of top companies in India by market cap (example)
companies = [
    {"symbol": "RELIANCE.BSE", "name": "Reliance Industries Limited"},
    {"symbol": "TCS.BSE", "name": "Tata Consultancy Services Limited"},
    {"symbol": "HDFCBANK.BSE", "name": "HDFC Bank Limited"},
    {"symbol": "HINDUNILVR.BSE", "name": "Hindustan Unilever Limited"},
    {"symbol": "INFY.BSE", "name": "Infosys Limited"},
    {"symbol": "BAJFINANCE.BSE", "name": "Bajaj Finance Limited"},
    {"symbol": "ICICIBANK.BSE", "name": "ICICI Bank Limited"},
    {"symbol": "KOTAKBANK.BSE", "name": "Kotak Mahindra Bank Limited"},
    {"symbol": "ITC.BSE", "name": "ITC Limited"},
    {"symbol": "SBIN.BSE", "name": "State Bank of India"}
]


# Initialize an empty DataFrame to store the data
df_combined = pd.DataFrame()

# Date range for fetching data
start_date = "2020-01-01"
end_date = "2024-01-31"

# Loop through each company
for company in companies:
    # Construct the API URL for TIME_SERIES_DAILY
    params = {
        "function": "TIME_SERIES_DAILY",
        "symbol": company["symbol"],
        "apikey": api_key,
        "outputsize": "full",  # Fetch full historical data
        "start_date": start_date,
        "end_date": end_date
    }

    # Make the API request
    response = requests.get(base_url, params=params)
    
    # Check if request was successful
    if response.status_code == 200:
        data = response.json()

        # Extract Time Series (Daily) data
        time_series = data.get("Time Series (Daily)")

        # Convert to DataFrame
        df = pd.DataFrame(time_series).T  # Transpose to have dates as rows

        # Reset index and rename columns
        df.reset_index(inplace=True)
        df.rename(columns={
            "index": "Date",
            "1. open": "Open",
            "4. close": "Close",
            "2. high": "High",
            "3. low": "Low",
            "5. volume": "Volume"
        }, inplace=True)

        # Add Company column
        df["Company"] = company["name"]

        # Append to combined DataFrame
        df_combined = pd.concat([df_combined, df], ignore_index=True)

    else:
        print(f"Failed to fetch data for {company['name']}")

# Save or further process df_combined DataFrame
df_combined.to_csv("top_companies_daily_data_2020_2024.csv", index=False)

print("Data fetched and saved successfully.")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# ...

# %% [markdown]
# Script for Daly DUMP of data

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import os

# Function to fetch data for a specific company and date
def fetch_company_data(api_key, company_symbol):
    base_url = "https://www.alphavantage.co/query"
    today = datetime.now().date()
    yesterday = today - timedelta(days=1)
    yesterday_str = yesterday.strftime("%Y-%m-%d")
    
    # Construct the API URL for TIME_SERIES_DAILY
    params = {
        "function": "TIME_SERIES_DAILY",
        "symbol": company_symbol,
        "apikey": api_key,
        "outputsize": "compact",  # Fetch only the latest 100 data points (adjust as per your needs)
        "datatype": "json",
        "date": yesterday_str
    }

    # Make the API request
    response = requests.get(base_url, params=params)

    # Check if request was successful
    if response.status_code == 200:
        data = response.json()

        # Extract Time Series (Daily) data for yesterday
        time_series = data.get("Time Series (Daily)", {})

        if time_series:
            # Convert to DataFrame
            df = pd.DataFrame([time_series[yesterday_str]]).T  # Transpose to have dates as rows

            # Reset index and rename columns
            df.reset_index(inplace=True)
            df.rename(columns={
                "index": "Date",
                "1. open": "Open",
                "4. close": "Close",
                "2. high": "High",
                "3. low": "Low",
                "5. volume": "Volume"
            }, inplace=True)

            # Add Company column
            df["Company"] = company_symbol

            return df
        
        else:
            print(f"No data found for {company_symbol} on {yesterday_str}")

    else:
        print(f"Failed to fetch data for {company_symbol} on {yesterday_str}")

    return None

# Define your API key
api_key = "your_api_key_here"  # Replace with your actual Alpha Vantage API key

# List of top 10 companies in India by market cap (example)
companies = [
    "RELIANCE.BSE",
    "TCS.BSE",
    "HDFCBANK.BSE",
    "HINDUNILVR.BSE",
    "INFY.BSE",
    "BAJFINANCE.BSE",
    "ICICIBANK.BSE",
    "KOTAKBANK.BSE",
    "ITC.BSE",
    "SBIN.BSE"
]

# Initialize an empty DataFrame to store the data
df_combined = pd.DataFrame()

# Loop through each company
for company_symbol in companies:
    # Fetch data for the company
    company_data = fetch_company_data(api_key, company_symbol)
    
    if company_data is not None:
        # Append company data to combined DataFrame
        df_combined = pd.concat([df_combined, company_data], ignore_index=True)

# Save the combined DataFrame to a CSV file
output_dir = "daily_data_dump"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

output_file = f"{output_dir}/top_10_companies_daily_data_{yesterday_str}.csv"
df_combined.to_csv(output_file, index=False)

print(f"Data fetched and saved successfully to {output_file}.")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# ...
